# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import numpy as np
df=pd.read_excel('health.xlsx')

# %%
df['overweight']=(df['weight']/(df['height']/100)**2>25).astype(int)
print(df)
# Out:
#      id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0     0  18393       2     168      62    110     80            0     0
# 1     1  20228       1     156      85    140     90            1     0
# 2     2  18857       1     165      64    130     70            1     0
# 3     3  17623       2     169      82    150    100            0     0
# 6     9  22113       1     157      93    130     80            1     0
# ..  ...    ...     ...     ...     ...    ...    ...          ...   ...
# 89  122  19480       2     172      87    120     80            0     0
# 90  123  23230       1     160      82    140    100            0     0
# 92  125  18752       2     173      76    150     90            0     0
# 93  126  22821       2     168      80    160    100            0     0
# 96  131  19258       2     165      65    110     70            0     0
#
#     smoke  alco  active  cardio  overweight
# 0       0     0       1       0           0
# 1       0     0       1       1           1
# 2       0     0       0       1           0
# 3       0     0       1       1           1
# 6       0     0       1       0           1
# ..    ...   ...     ...     ...         ...
# 89      0     0       0       0           1
# 90      0     0       1       0           1
# 92      0     0       1       1           1
# 93      0     0       1       0           1
# 96      0     0       1       0           0
#
# [66 rows x 14 columns]
# C:\Users\janan\AppData\Local\Temp\ipykernel_16420\585891583.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['overweight']=(df['weight']/(df['height']/100)**2>25).astype(int)

# %%
#Normalize cholestrol and glucose data
df['cholesterol'] = (df['cholesterol'] > 1).astype(int)
df['gluc'] = (df['gluc'] > 1).astype(int)
print(df)
# Out:
#      id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0     0  18393       2     168      62    110     80            0     0
# 1     1  20228       1     156      85    140     90            0     0
# 2     2  18857       1     165      64    130     70            0     0
# 3     3  17623       2     169      82    150    100            0     0
# 6     9  22113       1     157      93    130     80            0     0
# ..  ...    ...     ...     ...     ...    ...    ...          ...   ...
# 89  122  19480       2     172      87    120     80            0     0
# 90  123  23230       1     160      82    140    100            0     0
# 92  125  18752       2     173      76    150     90            0     0
# 93  126  22821       2     168      80    160    100            0     0
# 96  131  19258       2     165      65    110     70            0     0
#
#     smoke  alco  active  cardio  overweight
# 0       0     0       1       0           0
# 1       0     0       1       1           1
# 2       0     0       0       1           0
# 3       0     0       1       1           1
# 6       0     0       1       0           1
# ..    ...   ...     ...     ...         ...
# 89      0     0       0       0           1
# 90      0     0       1       0           1
# 92      0     0       1       1           1
# 93      0     0       1       0           1
# 96      0     0       1       0           0
#
# [66 rows x 14 columns]
# C:\Users\janan\AppData\Local\Temp\ipykernel_16420\1628285897.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cholesterol'] = (df['cholesterol'] > 1).astype(int)
# C:\Users\janan\AppData\Local\Temp\ipykernel_16420\1628285897.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gluc'] = (df['gluc'] > 1).astype(int)

# %%
#  Convert the data into long format and create a chart
df_cat = pd.melt(df, id_vars=['cardio'], value_vars=['cholesterol', 'gluc', 'alco', 'active', 'smoke'])
sns.catplot(data=df_cat, kind='count', x='variable', hue='value', col='cardio')

# %%
#  Clean the data
df = df[(df['ap_lo'] <= df['ap_hi']) &
        (df['height'] >= df['height'].quantile(0.025)) &
        (df['height'] <= df['height'].quantile(0.975)) &
        (df['weight'] >= df['weight'].quantile(0.025)) &
        (df['weight'] <= df['weight'].quantile(0.975))]

# %%
#  Create a correlation matrix and plot it
corr_matrix = df.corr()
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', mask=mask)
# Out:
# <Axes: >
